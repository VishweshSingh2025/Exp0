# %% [markdown]
# <a href="https://colab.research.google.com/github/VishweshSingh2025/Exp0/blob/main/Pract0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Explanatory Data Analysis
# ##Basics of Python
# ###Expt-0

# %% [markdown]
# EXP 0: Introduction to Python

# %%
# Vishwesh Singh / 25070123126

print("Vishwesh Singh")
# Out:
# Vishwesh Singh

# %%
print(2)
# Out:
# 2

# %%
ar=[1,2,5]
print(ar)
# Out:
# [1, 2, 5]

# %%
print("Vishwesh Singh\n",2,"\n",ar)
# Out:
# Vishwesh Singh
#  2
#  [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="Vishwesh Singh"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Vishwesh Singh
